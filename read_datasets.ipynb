# %% [markdown]
# <a href="https://colab.research.google.com/github/haysho2260/466Labs/blob/main/read_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import zipfile
import requests
from io import BytesIO

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_features = pd.read_csv('https://media.githubusercontent.com/media/PabloBelloDelpon/Spotify_paper/master/spotify_features_data.csv', delimiter='\t')
df_features.head()
# Out:
#      country        date  track_danceability  track_energy  track_key  \
# 0  Argentina  2017-01-01           -0.282567      2.816441   0.320923
# 1  Argentina  2017-01-02           -1.503891      1.622642   1.145687
# 2  Argentina  2017-01-03           -1.561789      1.711798   0.833614
# 3  Argentina  2017-01-04           -1.795726      1.739091   0.766741
# 4  Argentina  2017-01-05           -1.523060      1.747986   0.900487
#
#    track_loudness  track_mode  track_speechiness  track_acousticness  \
# 0        1.068775    0.103475          -1.146558           -2.339866
# 1        0.560420    0.515852          -1.126886           -1.781023
# 2        0.778423    0.309664          -1.161303           -1.860436
# 3        0.552843    0.309664          -1.018875           -1.831586
# 4        0.768336    0.309664          -0.916219           -1.850303
#
#    track_instrumentalness  track_liveness  track_valence  track_tempo  \
# 0               -1.153487        0.732844       4.698593    -1.286186
# 1               -0.871937       -0.833227       1.500897    -1.532542
# 2               -0.871937       -0.533889       1.509742    -1.441048
# 3               -0.871281       -0.939987       1.516893    -1.471167
# 4               -0.896654       -0.597103       1.765854    -1.374252
#
#    track_duration_ms
# 0          -1.735134
# 1          -0.048523
# 2          -0.169919
# 3          -0.401584
# 4          -0.518515

# %%
response = requests.get("https://github.com/PabloBelloDelpon/Spotify_paper/raw/master/itunes_data.csv.zip")
with zipfile.ZipFile(BytesIO(response.content)) as z:
  # Extract the CSV file
  csv_filename = z.namelist()[0]
  with z.open(csv_filename) as f:
      # Read the CSV file into a DataFrame
      df_itunes = pd.read_csv(f)
df_itunes.head()
# Out:
#    wave        date  position  \
# 0   1.0  2013-08-14       1.0
# 1   1.0  2013-08-14       2.0
# 2   1.0  2013-08-14       3.0
# 3   1.0  2013-08-14       4.0
# 4   1.0  2013-08-14       5.0
#
#                                                track country_id  \
# 0                              Ellie Goulding - Burn         uk
# 1                                Avicii - Wake Me Up         uk
# 2                               Lady Gaga - Applause         uk
# 3                        Miley Cyrus - We Can't Stop         uk
# 4  Lana Del Rey & Cedric Gervais - Summertime Sad...         uk
#
#           country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
response = requests.get("https://github.com/PabloBelloDelpon/Spotify_paper/raw/master/spotify_data.csv.zip")
with zipfile.ZipFile(BytesIO(response.content)) as z:
  # Extract the CSV file
  csv_filename = z.namelist()[0]
  with z.open(csv_filename) as f:
      # Read the CSV file into a DataFrame
      df_spotify = pd.read_csv(f)
df_spotify.head()
# Out:
#          country        date  position          artist  streams  \
# 0  United States  2020-06-20         1          DaBaby  1562649
# 1  United States  2020-06-20         2  StaySolidRocky  1065084
# 2  United States  2020-06-20         3      The Weeknd  1007630
# 3  United States  2020-06-20         4       Lil Mosey   963554
# 4  United States  2020-06-20         5    Harry Styles   905569
#
#                  track_id                  label_1    origin_song
# 0  7ytR5pFWmSjzHJIeQkgog4  South Coast Music Group  United States
# 1  5RqR4ZCCKJDcBLIn4sih9l                 Columbia  United States
# 2  0VjIjW4GlUZAMYd2vXMi3b         Republic Records  United States
# 3  22LAwLoDA5b4AaGSkg6bKW             Mogul Vision  United States
# 4  6UelLqGlWMcVH1E5c4H7lY                 Columbia  United States

# %%
df_gdp = pd.read_csv("https://github.com/haysho2260/466finalProject/raw/main/gdp_dataset.csv")
df_gdp = df_gdp[["Country Name", "2017", "2018", "2019", "2020", "2021", "2022"]]
df_gdp.head()
# Out:
#                   Country Name          2017          2018          2019  \
# 0                        Aruba  29329.081747  30918.483584  31902.809818
# 1  Africa Eastern and Southern   1625.286236   1558.307482   1507.982881
# 2                  Afghanistan    526.140801    492.090632    497.741429
# 3   Africa Western and Central   1590.277754   1735.374911   1812.446822
# 4                       Angola   2439.374441   2540.508878   2191.347764
#
#            2020          2021          2022
# 0  24008.127822  29127.759384  33300.838819
# 1   1355.805923   1545.613215   1644.062829
# 2    512.055098    355.777826           NaN
# 3   1688.075575   1766.943618   1785.312219
# 4   1450.905112   1927.474078   3000.444231
